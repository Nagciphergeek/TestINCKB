# %% [markdown]
# # Incident2KB Inference Pipeline Notebook
# This notebook demonstrates loading a saved artefact and running a predictive pipeline for a new incident note.

# %%
import joblib
from pathlib import Path

model_path = Path('models/logistic_regression.pkl')
vector_path = Path('models/tfidf_vectorizer.pkl')

print('Model path:', model_path)
print('Vectorizer path:', vector_path)

# Example code only; actual saved files need to exist.
# model = joblib.load(model_path)
# vectorizer = joblib.load(vector_path)
# sample = ['API gateway returns 502 errors during peak traffic']
# predicted = model.predict(vectorizer.transform(sample))
# print('Predicted label:', predicted[0])
